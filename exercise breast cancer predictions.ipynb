# %% [markdown]
# Name: parmvir singh bali
# Student ID: 100843502

# %%
#Load Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Load Dataset
dataset = pd.read_csv('./dataset.csv')
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 569 non-null    int64
#  1   diagnosis          569 non-null    object
#  2   radius_mean        569 non-null    float64
#  3   texture_mean       569 non-null    float64
#  4   perimeter_mean     569 non-null    float64
#  5   area_mean          569 non-null    float64
#  6   smoothness_mean    569 non-null    float64
#  7   compactness_mean   569 non-null    float64
#  8   concavity_mean     569 non-null    float64
#  9   points_mean        569 non-null    float64
#  10  symmetry_mean      569 non-null    float64
#  11  dimension_mean     569 non-null    float64
#  12  radius_se          569 non-null    float64
#  13  texture_se         569 non-null    float64
#  14  perimeter_se       569 non-null    float64
# ...

# %%
dataset.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# count       569.000000        569.000000      569.000000   569.000000
# mean          0.096360          0.104341        0.088799     0.048919
# std           0.014064          0.052813        0.079720     0.038803
# ...

# %%
dataset.isna().sum()
# Out:
# id                   0
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %%
dataset.describe()
plt.hist(dataset['diagnosis'])
plt.title('Diagnosis (M=1 , B=0)')
plt.show()

# %%
sns.histplot(dataset['radius_mean'], kde=True)
plt.show()

# %%
sns.boxplot(x='diagnosis', y='radius_mean', data=dataset)
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Split the dataset into X (features) and y (target)
X = dataset.drop(['diagnosis', 'id'], axis=1)
y = dataset['diagnosis']
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
knn = KNeighborsClassifier()

dt.fit(X_train, y_train)
rf.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Scale the Data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
# Create the KNN model and perform 10-fold cross-validation
knn = KNeighborsClassifier()
knn_scores = cross_val_score(knn, X, y, cv=10)

# %%
# Create the DT model and perform 10-fold cross-validation
dt = DecisionTreeClassifier()
dt_scores = cross_val_score(dt, X, y, cv=10)

# %%
# Create the RF model and perform 10-fold cross-validation
rf = RandomForestClassifier()
rf_scores = cross_val_score(rf, X, y, cv=10)

# %%
# Print the accuracy scores
print("KNN Accuracy: %0.2f (+/- %0.2f)" % (knn_scores.mean(), knn_scores.std() * 2))
print("DT Accuracy: %0.2f (+/- %0.2f)" % (dt_scores.mean(), dt_scores.std() * 2))
print("RF Accuracy: %0.2f (+/- %0.2f)" % (rf_scores.mean(), rf_scores.std() * 2))
# Out:
# KNN Accuracy: 0.93 (+/- 0.06)
# DT Accuracy: 0.91 (+/- 0.04)
# RF Accuracy: 0.96 (+/- 0.04)

# %% [markdown]
# so ramdon forest has the maximium accuracy of 96% followed by  knn and decision tree  0f 93% and 91% respectively.

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the KNN model
knn = KNeighborsClassifier()

# Set the hyperparameters to be tuned
knn_param_grid = {'n_neighbors': [3, 5, 7, 9]}

# Create the grid search object and fit the data
knn_grid = GridSearchCV(knn, knn_param_grid, cv=10)
knn_grid.fit(X, y)

# Print the best hyperparameters and accuracy score
print("Best KNN Parameters: ", knn_grid.best_params_)
print("Best KNN Accuracy: %0.2f" % (knn_grid.best_score_))

# Create the DT model
dt = DecisionTreeClassifier()

# Set the hyperparameters to be tuned
dt_param_grid = {'max_depth': [3, 5, 7, 9]}

# Create the grid search object and fit the data
dt_grid = GridSearchCV(dt, dt_param_grid, cv=10)
dt_grid.fit(X, y)

# Print the best hyperparameters and accuracy score
print("Best DT Parameters: ", dt_grid.best_params_)
print("Best DT Accuracy: %0.2f" % (dt_grid.best_score_))

# Create the RF model
rf = RandomForestClassifier()

# Set the hyperparameters to be tuned
rf_param_grid = {'n_estimators': [10, 50, 100, 200],
                 'max_depth': [3, 5, 7, 9]}

# Create the grid search object and fit the data
rf_grid = GridSearchCV(rf, rf_param_grid, cv=10)
rf_grid.fit(X, y)

# Print the best hyperparameters and accuracy score
print("Best RF Parameters: ", rf_grid.best_params_)
print("Best RF Accuracy: %0.2f" % (rf_grid.best_score_))
# Out:
# Best KNN Parameters:  {'n_neighbors': 9}
# Best KNN Accuracy: 0.94
# Best DT Parameters:  {'max_depth': 5}
# Best DT Accuracy: 0.93
# Best RF Parameters:  {'max_depth': 9, 'n_estimators': 10}
# Best RF Accuracy: 0.96

# %% [markdown]
# The goal of hyperparameter tuning is to find the optimal set of hyperparameters that will maximize the performance of the machine learning model on the task at hand. This is typically done by trying out different combinations of hyperparameters and evaluating their performance on a validation set.
# So after hyperparamter tuning the accuracy of random forest remain the samewhich is 96% whereras accuracy of knn increases from 93 to 94% and decision tree increases from 91 to 93%.. Overall random forest has the best accuracy.
